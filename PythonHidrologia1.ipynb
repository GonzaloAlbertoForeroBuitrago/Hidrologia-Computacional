# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime

# %%
cd/content/sample_data
# Out:
# /content/sample_data

# %%
pp= pd.read_csv("/content/StaritaDiarios96_2019prec.csv.csv",index_col=16,parse_dates=True)

# %%
#pp_= pp.set_index("Fecha") # si se quiere cambiar el indice

# %%
pp.head()
# Out:
#             CodigoEstacion         NombreEstacion  ...  Calificador  NivelAprobacion
# Fecha                                              ...
# 1996-01-01        36010030  SANTA RITA [36010030]  ...          NaN              900
# 1996-01-02        36010030  SANTA RITA [36010030]  ...          NaN              900
# 1996-01-03        36010030  SANTA RITA [36010030]  ...          NaN              900
# 1996-01-04        36010030  SANTA RITA [36010030]  ...          NaN              900
# 1996-01-05        36010030  SANTA RITA [36010030]  ...          NaN              900
#
# [5 rows x 20 columns]

# %%
pp.count()
# Out:
# CodigoEstacion      7968
# NombreEstacion      7968
# Latitud             7968
# Longitud            7968
# Altitud             7968
# Categoria           7968
# Entidad             7968
# AreaOperativa       7968
# Departamento        7968
# Municipio           7968
# FechaInstalacion    7968
# FechaSuspension        0
# IdParametro         7968
# Etiqueta            7968
# DescripcionSerie    7968
# Frecuencia          7968
# Valor               7968
# Grado               7968
# Calificador           19
# NivelAprobacion     7968
# dtype: int64

# %%
pp.tail()
# Out:
#             CodigoEstacion         NombreEstacion  ...  Calificador  NivelAprobacion
# Fecha                                              ...
# 2019-12-27        36010030  SANTA RITA [36010030]  ...          NaN              900
# 2019-12-28        36010030  SANTA RITA [36010030]  ...          NaN              900
# 2019-12-29        36010030  SANTA RITA [36010030]  ...          NaN              900
# 2019-12-30        36010030  SANTA RITA [36010030]  ...          NaN              900
# 2019-12-31        36010030  SANTA RITA [36010030]  ...          NaN              900
#
# [5 rows x 20 columns]

# %%
#pp_.reset_index(drop=True, inplace=True)# En caso de no empezar en 0

# %%
pp.describe()
# Out:
#        CodigoEstacion       Latitud  ...   Grado  NivelAprobacion
# count          7968.0  7.968000e+03  ...  7968.0      7968.000000
# mean       36010030.0  5.934250e+00  ...    50.0       902.284137
# std               0.0  9.708399e-13  ...     0.0        21.252452
# min        36010030.0  5.934250e+00  ...    50.0       900.000000
# 25%        36010030.0  5.934250e+00  ...    50.0       900.000000
# 50%        36010030.0  5.934250e+00  ...    50.0       900.000000
# 75%        36010030.0  5.934250e+00  ...    50.0       900.000000
# max        36010030.0  5.934250e+00  ...    50.0      1100.000000
#
# [8 rows x 8 columns]

# %%
pp["Valor"].plot(kind="area")

# %%
pp["Valor"].hist()

# %%
pp[pp['Valor']>0].boxplot()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
pp.filtered = pd.to_numeric(pp["Valor"], errors="coerce")  #si se quisiera convertir a numero una columna y corregir errores de esa columna
pp.describe()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
#        CodigoEstacion       Latitud  ...   Grado  NivelAprobacion
# count          7968.0  7.968000e+03  ...  7968.0      7968.000000
# mean       36010030.0  5.934250e+00  ...    50.0       902.284137
# std               0.0  9.708399e-13  ...     0.0        21.252452
# min        36010030.0  5.934250e+00  ...    50.0       900.000000
# 25%        36010030.0  5.934250e+00  ...    50.0       900.000000
# 50%        36010030.0  5.934250e+00  ...    50.0       900.000000
# 75%        36010030.0  5.934250e+00  ...    50.0       900.000000
# max        36010030.0  5.934250e+00  ...    50.0      1100.000000
#
# [8 rows x 8 columns]

# %%
pp.dtypes
# Out:
# CodigoEstacion        int64
# NombreEstacion       object
# Latitud             float64
# Longitud            float64
# Altitud               int64
# Categoria            object
# Entidad              object
# AreaOperativa        object
# Departamento         object
# Municipio            object
# FechaInstalacion     object
# FechaSuspension     float64
# IdParametro          object
# Etiqueta             object
# DescripcionSerie     object
# Frecuencia           object
# Valor               float64
# Grado                 int64
# Calificador          object
# NivelAprobacion       int64
# dtype: object

# %%
pp.index.min(), pp.index.max()
# Out:
# (Timestamp('1996-01-01 00:00:00'), Timestamp('2019-12-31 00:00:00'))

# %%
AñoMaximo=pp['Valor'].loc['2012-01-01':'2012-12-31']
AñoMaximo.plot()

# %%
pp.dtypes
# Out:
# CodigoEstacion        int64
# NombreEstacion       object
# Latitud             float64
# Longitud            float64
# Altitud               int64
# Categoria            object
# Entidad              object
# AreaOperativa        object
# Departamento         object
# Municipio            object
# FechaInstalacion     object
# FechaSuspension     float64
# IdParametro          object
# Etiqueta             object
# DescripcionSerie     object
# Frecuencia           object
# Valor               float64
# Grado                 int64
# Calificador          object
# NivelAprobacion       int64
# dtype: object

# %%
pp.dtypes
# Out:
# CodigoEstacion        int64
# NombreEstacion       object
# Latitud             float64
# Longitud            float64
# Altitud               int64
# Categoria            object
# Entidad              object
# AreaOperativa        object
# Departamento         object
# Municipio            object
# FechaInstalacion     object
# FechaSuspension     float64
# IdParametro          object
# Etiqueta             object
# DescripcionSerie     object
# Frecuencia           object
# Valor               float64
# Grado                 int64
# Calificador          object
# NivelAprobacion       int64
# dtype: object

# %%
pp.index[-1]-pp.index[0] # cuando puedo hacer operaciones es que esta en DateTime la fecha
# Out:
# Timedelta('8765 days 00:00:00')

# %%
pp.index[0]+datetime.timedelta(days=200)     # 200 dias despues del dia inicial
# Out:
# Timestamp('1996-07-19 00:00:00')

# %%
pp['day']= pp.index.day
pp['month']= pp.index.month
pp['year']= pp.index.year # para que salga una columna adicional con los dias, meses o años
pp
# Out:
#             CodigoEstacion         NombreEstacion  Latitud  ...  day  month  year
# Fecha                                                       ...
# 1996-01-01        36010030  SANTA RITA [36010030]  5.93425  ...    1      1  1996
# 1996-01-02        36010030  SANTA RITA [36010030]  5.93425  ...    2      1  1996
# 1996-01-03        36010030  SANTA RITA [36010030]  5.93425  ...    3      1  1996
# 1996-01-04        36010030  SANTA RITA [36010030]  5.93425  ...    4      1  1996
# 1996-01-05        36010030  SANTA RITA [36010030]  5.93425  ...    5      1  1996
# ...                    ...                    ...      ...  ...  ...    ...   ...
# 2019-12-27        36010030  SANTA RITA [36010030]  5.93425  ...   27     12  2019
# 2019-12-28        36010030  SANTA RITA [36010030]  5.93425  ...   28     12  2019
# 2019-12-29        36010030  SANTA RITA [36010030]  5.93425  ...   29     12  2019
# 2019-12-30        36010030  SANTA RITA [36010030]  5.93425  ...   30     12  2019
# ...

# %%
year = pp.groupby('year').count()
year
# Out:
#       CodigoEstacion  NombreEstacion  Latitud  ...  NivelAprobacion  day  month
# year                                           ...
# 1996             143             143      143  ...              143  143    143
# 1997             365             365      365  ...              365  365    365
# 1998             365             365      365  ...              365  365    365
# 1999             365             365      365  ...              365  365    365
# 2000             365             365      365  ...              365  365    365
# 2001             243             243      243  ...              243  243    243
# 2002             364             364      364  ...              364  364    364
# 2003             364             364      364  ...              364  364    364
# 2004             123             123      123  ...              123  123    123
# 2005             333             333      333  ...              333  333    333
# ...

# %%
month = pp.groupby('month').count()
month
# Out:
#        CodigoEstacion  NombreEstacion  Latitud  ...  NivelAprobacion  day  year
# month                                           ...
# 1                 744             744      744  ...              744  744   744
# 2                 618             618      618  ...              618  618   618
# 3                 685             685      685  ...              685  685   685
# 4                 670             670      670  ...              670  670   670
# 5                 682             682      682  ...              682  682   682
# 6                 655             655      655  ...              655  655   655
# 7                 663             663      663  ...              663  663   663
# 8                 609             609      609  ...              609  609   609
# 9                 569             569      569  ...              569  569   569
# 10                681             681      681  ...              681  681   681
# ...

# %%
day = pp.groupby('day').count()
day
# Out:
#      CodigoEstacion  NombreEstacion  Latitud  ...  NivelAprobacion  month  year
# day                                           ...
# 1               263             263      263  ...              263    263   263
# 2               263             263      263  ...              263    263   263
# 3               263             263      263  ...              263    263   263
# 4               264             264      264  ...              264    264   264
# 5               263             263      263  ...              263    263   263
# 6               261             261      261  ...              261    261   261
# 7               261             261      261  ...              261    261   261
# 8               262             262      262  ...              262    262   262
# 9               262             262      262  ...              262    262   262
# 10              261             261      261  ...              261    261   261
# ...

# %%
ppMensual=pp[["month","Valor"]].groupby("month").sum()
ppMensual
ppMensual.plot()

# %%
ppMensual=pp[["month","Valor"]].groupby("month").sum()
ppMensual
# Out:
#         Valor
# month
# 1       248.1
# 2       644.2
# 3      1310.4
# 4      4653.5
# 5      6059.4
# 6      5663.7
# 7      5323.4
# 8      3949.0
# 9      3585.8
# 10     3840.0
# 11     2868.7
# 12      759.6

# %%
ppMensual.plot(kind='bar')

# %%
ppMensual.to_excel('/content/sample_data/Ppensual.xls')

# %%
Caudal=pd.read_csv('/content/sample_data/CaudalAriporoMedDiario1996_2019.csv.csv',index_col=16,parse_dates=True)

# %%
Caudal.dtypes
# Out:
# CodigoEstacion        int64
# NombreEstacion       object
# Latitud             float64
# Longitud            float64
# Altitud               int64
# Categoria            object
# Entidad              object
# AreaOperativa        object
# Departamento         object
# Municipio            object
# FechaInstalacion     object
# FechaSuspension     float64
# IdParametro          object
# Etiqueta             object
# DescripcionSerie     object
# Frecuencia           object
# Valor               float64
# Grado                 int64
# Calificador          object
# NivelAprobacion       int64
# dtype: object

# %%
Caudal.head()
# Out:
#             CodigoEstacion  ... NivelAprobacion
# Fecha                       ...
# 1996-05-01        36017010  ...             900
# 1996-05-02        36017010  ...             900
# 1996-05-03        36017010  ...             900
# 1996-05-04        36017010  ...             900
# 1996-05-05        36017010  ...             900
#
# [5 rows x 20 columns]

# %%
Caudal['Valor'].plot()

# %%
Caudal=Caudal.loc[pp.index.min():pp.index.max()]
fig,ax=plt.subplots(figsize=(15,6))
Caudal['Valor'].plot(ax=ax, label='Caudal m3/dia')
pp['Valor'].plot(ax=ax, label= 'Precipitacion ')
ax.legend()

# %%
Caudal=Caudal.loc[pp.index.min():pp.index.max()]
fig,ax=plt.subplots(figsize=(15,6))
Caudal['Valor'].plot(ax=ax, label='Caudal m3/dia')
ax.legend()
ax1=ax.twinx()
pp['Valor'].plot(ax=ax1, label= 'Precipitacion ', color='orangered')
ax1.set_ylim(ax1.get_ylim()[::-1])
ax1.legend()
fig.savefig('/content/sample_data/precipitacion_y_caudal.png')
